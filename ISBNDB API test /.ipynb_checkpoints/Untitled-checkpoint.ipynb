# %%
import pandas as pd 
import requests 
import json 


import warnings 
warnings.filterwarnings('ignore')
data = pd.read_csv('books.csv')
data.sample(10)
# Out:
#                                                  Title           Author  \
# 525                                  Bleach, Volume 01        Tite Kubo
# 303  Codex Seraphinianus. Ein Orbis Pictus des Univ...   Luigi Serafini
# 750          Dark Lover (Black Dagger Brotherhood, #1)        J.R. Ward
# 223                      Night (The Night Trilogy, #1)      Elie Wiesel
# 780                            Twilight (Twilight, #1)  Stephenie Meyer
# 520                              Fruits Basket, Vol. 2   Natsuki Takaya
# 700          Bridget Jones's Diary (Bridget Jones, #1)   Helen Fielding
# 480                             Fruits Basket, Vol. 19   Natsuki Takaya
# 582                           Poison Study (Study, #1)  Maria V. Snyder
# 36                                        Mustard Seed    Laila Ibrahim
#
#             Genre  PAges  Rating                  Publisher
# 525        Anime     200    4.22              VIZ Media LLC
# ...

# %%
# Out:
# {'kind': 'books#volumes', 'totalItems': 0}
