# %%
import pandas as pd
import requests as req 
import json 

import warnings
warnings.filterwarnings('ignore')

data = pd.read_csv('books.csv') # converting out data into a dataframe 


genre_list = data['Genre'].tolist()
genre_list

def unique_list(genre_list):
    list_set = set(genre_list)
    unique_list = list(list_set)
    for x in unique_list:
        print(x)


def program_output(start_search):
    if start_search == "Tailored":
        output = unique_list(genre_list)
        
    elif start_search == "Lucky":
        dsample = data.sample(10)  
        
    else:
        print("Invalid Entry ")
        
    return(dsample)

# genre database

genre_pref = input("Enter Your Favorite Genre  From The List of Genres:")
genre = books_db['Genre']== genre_pref
genre_db = books_db[genre]
genre_db
# Out:
# Enter Your Favorite Genre  From The List of Genres:Romance
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-bd141261e543> in <module>
#      34
#      35 genre_pref = input("Enter Your Favorite Genre  From The List of Genres:")
# ---> 36 genre = books_db['Genre']== genre_pref
#      37 genre_db = books_db[genre]
#      38 genre_db
#
# NameError: name 'books_db' is not defined

# %%
start_search = input("Enter Lucky or Tailored")
program_output(start_search)
# Out:
# Enter Lucky or TailoredLucky
#                                                   Title             Author  \
# 2351                                        The Odyssey              Homer
# 1372                   Force of Nature (Aaron Falk, #2)        Jane Harper
# 6781                                        Meditations    Marcus Aurelius
# 5789  Breaking the Spell: Religion as a Natural Phen...  Daniel C. Dennett
# 187                                 An Object of Beauty       Steve Martin
# 299   Ouran High School Host Club, Vol. 9 (Ouran Hig...       Bisco Hatori
# 3491                                  The Essex Serpent        Sarah Perry
# 1603                            Chez Panisse Vegetables       Alice Waters
# 2126                                  Superman: Red Son        Mark Millar
# 5930  The Melancholy Death of Oyster Boy and Other S...         Tim Burton
#
#                    Genre  PAges  Rating                  Publisher    Year
# ...
