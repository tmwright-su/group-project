# %%
import pandas as pd 
import requests 
import json 


import warnings 
warnings.filterwarnings('ignore')
data = pd.read_csv('books.csv')
data.sample(10)
# Out:
#                                                  Title           Author  \
# 525                                  Bleach, Volume 01        Tite Kubo
# 303  Codex Seraphinianus. Ein Orbis Pictus des Univ...   Luigi Serafini
# 750          Dark Lover (Black Dagger Brotherhood, #1)        J.R. Ward
# 223                      Night (The Night Trilogy, #1)      Elie Wiesel
# 780                            Twilight (Twilight, #1)  Stephenie Meyer
# 520                              Fruits Basket, Vol. 2   Natsuki Takaya
# 700          Bridget Jones's Diary (Bridget Jones, #1)   Helen Fielding
# 480                             Fruits Basket, Vol. 19   Natsuki Takaya
# 582                           Poison Study (Study, #1)  Maria V. Snyder
# 36                                        Mustard Seed    Laila Ibrahim
#
#             Genre  PAges  Rating                  Publisher
# 525        Anime     200    4.22              VIZ Media LLC
# ...

# %%
import requests 
import json

# %%
 # List my public Google+ activities.
key_words = 'romance'
key = 'AIzaSyD-bqY8cCeGU-EdwKU8QU5tCsDp6XVNNXo'
    
url = 'https://www.googleapis.com/books/v1/volumes?q=%s+subject:keyes&key=%s' % (key_words, key)

response = requests.get(url)
response.text
# Out:
# '{\n "kind": "books#volumes",\n "totalItems": 0\n}\n'

# %%
import pandas as pd

# %%
website = 'http://www.isfdb.org/cgi-bin/fc.cgi'

data = pd.read_html(website)
data[1]
# Out:
#             0                                1   \
# 0         Date                        Author(s)
# 1   2019-04-25                      Jodi Taylor
# 2   2019-04-25                  Roberto Calasso
# 3   2019-04-26                   Klaus N. Frick
# 4   2019-04-27                 Fuminori Teshima
# 5   2019-04-27                       uncredited
# 6   2019-04-28                         Yu Okano
# 7   2019-04-29            David Hair, Cath Mayo
# 8   2019-04-30             Raymond A. Villareal
# 9   2019-04-30                   James A. Moore
# 10  2019-04-30                       Andy Clark
# 11  2019-04-30                    Troy Cummings
# 12  2019-04-30                    Troy Cummings
# 13  2019-04-30                     Tim Waggoner
# 14  2019-04-30                 Kelley Armstrong
# 15  2019-04-30                      H. G. Wells
# 16  2019-04-30                    J. A. Konrath
# 17  2019-04-30                      Tracey West
# ...

# %% [markdown]
# Inputs
# - 1. user type in genre
# - 2. random or personalized selection?
# - 3. 1-4 input how important is rating, 4 being highest
# - 4. long or short read 1-4, 4 being highest
# - 5. modern or old book 1-4, 4 being most modern
#
# Outputs
# - list of random books
# - or list of personalized selecitons
#
# Algorithm
# - import pandas as pd # using pandas to hold csv data
# - import requests # request information from csv file
# - import warnings
#
# - get info from csv file
# - read response as csv file
# - create pandas dataframe of response
#
# - input 1
# - input 2
# - input 3
# - input 4
# - input 5
#
# - list of genres available
#
# - input 1 (Enter a genre)
# - if input 2 is random
#     - stop all other inputs
#     - return random sample from books pd
# - if input 2 is a genre
#     - select all in that genre from pd store in variable
#     - continue for inputs
# - for book_rate in input 4:
#     - from returned values under genre input
#     - if rate 1
#         - return all book_rates
#     - if rate 2
#         - return book_rates >= 2.0
#     - if rate 3
#         - return book_rates >= 3.0
#     - if rate 4
#         - return book_rates >= 4.5
#     - store new values under input 2 variable
# - for book_length in input 4:
#     - from returned values under input 3 variable
#     - if rate 1
#         - return all book_lengths
#     - if rate 2
#         - return book_lengths <=200
#     - if rate 3
#         - return all book_lengths <= 300
#     - if rate 4
#         - return book_lengths > 300
#     - store new values under input 4 variable
# - for year_published in input 5
#     - if rate 1
#         - return books from all years
#     - if rate 2
#         - return years <= 1900
#     - if rate 3
#         - return years >= 1980
#     - if rate 4
#         - return years >= 2000
#     - store new values under input 5 variable
#
# return personalized dataframe (from input 5 variable)

# %%
import pandas as pd
import requests
import json
import warnings 
warnings.filterwarnings('ignore')

# %%
books = pd.read_csv('books.csv')

books.sample(5)
# Out:
#                                                  Title           Author  \
# 330             The Da Vinci Code (Robert Langdon, #2)        Dan Brown
# 564                   Angels' Blood (Guild Hunter, #1)     Nalini Singh
# 664        Pushing the Limits (Pushing the Limits, #1)    Katie McGarry
# 171  Destiny of the Republic: A Tale of Madness, Me...  Candice Millard
# 536                         Just the Sexiest Man Alive      Julie James
#
#          Genre  PAges  Rating          Publisher
# 330        Art    489    3.82             Anchor
# 564    Romance    339    4.11  Berkley Sensation
# 664    Romance    392    4.07     Harlequin Teen
# 171  Biography    339    4.21          Doubleday
# 536    Romance    296    3.93  Berkley Sensation

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-d3e83507f319> in <module>
#       2 genres = books.groupby('Genre')
#       3 for a, b in genres:
# ----> 4     p = genres.get_group('Title')
#       5     print (p)
#       6
#
# c:\users\sthay\appdata\local\programs\python\python36\lib\site-packages\pandas\core\groupby\groupby.py in get_group(self, name, obj)
#     875         inds = self._get_index(name)
#     876         if not len(inds):
# --> 877             raise KeyError(name)
#     878
#     879         return obj._take(inds, axis=self.axis)
#
# KeyError: 'Title'
